# %%
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
crypto_coin = pd.read_html("https://coinmarketcap.com/coins/")[0]

# %%
crypto_coin.head(20)
# Out:
#      #                  Name    Market Cap      Price    Volume (24h)  \
# 0    1           BTC Bitcoin  1.389913e+11   $8204.31  $5,925,230,000
# 1    2          ETH Ethereum  4.853381e+10    $493.06  $1,635,190,000
# 2    3            XRP Ripple  2.373598e+10  $0.607148    $383,097,000
# 3    4      BCH Bitcoin Cash  1.571401e+10    $922.21    $349,396,000
# 4    5          LTC Litecoin  8.364209e+09    $149.89    $401,895,000
# 5    6           ADA Cardano  4.354555e+09  $0.167954    $114,964,000
# 6    7           XLM Stellar  4.255448e+09  $0.229400     $44,832,300
# 7    8               NEO NEO  3.910790e+09     $60.17    $144,368,000
# 8    9            MIOTA IOTA  3.422408e+09      $1.23     $32,914,200
# 9   10            XMR Monero  3.141040e+09    $197.96     $37,189,400
# 10  11             DASH Dash  3.091887e+09    $387.98    $107,411,000
# 11  12               XEM NEM  2.412612e+09  $0.268068     $38,927,100
# 12  13  ETC Ethereum Classic  1.671499e+09     $16.59    $185,146,000
# 13  14             QTUM Qtum  1.439912e+09     $16.27    $242,474,000
# 14  15              LSK Lisk  1.132467e+09     $10.97     $21,127,600
# 15  16      BTG Bitcoin Gold  9.493117e+08     $56.16     $20,616,600
# 16  17             NANO Nano  9.219169e+08      $6.92     $27,359,700
# 17  18             ZEC Zcash  7.949832e+08    $222.91     $51,801,400
# 18  19             XVG Verge  6.777798e+08  $0.045925     $58,237,700
# 19  20           STEEM Steem  4.872480e+08      $1.91      $2,524,810
#
#        Circulating Supply Change (24h)  Price Graph (7d)
# 0          16,941,250 BTC       -4.28%               NaN
# 1          98,434,889 ETH       -6.77%               NaN
# 2    39,094,227,299 XRP *       -6.20%               NaN
# 3          17,039,513 BCH       -5.59%               NaN
# 4          55,803,806 LTC       -7.11%               NaN
# 5    25,927,070,538 ADA *      -10.02%               NaN
# 6    18,550,337,922 XLM *       -4.73%               NaN
# 7        65,000,000 NEO *       -8.84%               NaN
# 8   2,779,530,283 MIOTA *       -7.60%               NaN
# 9          15,867,367 XMR       -6.77%               NaN
# 10         7,969,254 DASH       -6.66%               NaN
# 11    8,999,999,999 XEM *       -8.76%               NaN
# 12        100,772,860 ETC       -8.90%               NaN
# 13      88,477,656 QTUM *      -10.21%               NaN
# 14      103,234,978 LSK *       -7.26%               NaN
# 15         16,904,511 BTG       -8.65%               NaN
# 16     133,248,289 NANO *       -9.86%               NaN
# 17          3,566,306 ZEC       -7.47%               NaN
# 18     14,758,469,444 XVG       10.50%               NaN
# 19    254,738,235 STEEM *       -6.42%               NaN

# %%
r  = requests.get("https://coinmarketcap.com/coins/")
data = r.text
soup = BeautifulSoup(data)
# Out:
# /Users/vsanjeev/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/vsanjeev/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
currencies_soup = (soup.find(id="currencies"))
currencies_dict = {}
for link in currencies_soup.find_all('a'):
    if len(currencies_dict) < 20:
        link_temp = link.get('href')
        if 'currencies' in link_temp and '#charts' not in link_temp and '#markets' not in link_temp:
            currencies_dict[link_temp.split('/')[2]] = link_temp
    else:
        break
currencies_dict
# Out:
# {'bitcoin': '/currencies/bitcoin/',
#  'bitcoin-cash': '/currencies/bitcoin-cash/',
#  'bitcoin-gold': '/currencies/bitcoin-gold/',
#  'cardano': '/currencies/cardano/',
#  'dash': '/currencies/dash/',
#  'ethereum': '/currencies/ethereum/',
#  'ethereum-classic': '/currencies/ethereum-classic/',
#  'iota': '/currencies/iota/',
#  'lisk': '/currencies/lisk/',
#  'litecoin': '/currencies/litecoin/',
#  'monero': '/currencies/monero/',
#  'nano': '/currencies/nano/',
#  'nem': '/currencies/nem/',
#  'neo': '/currencies/neo/',
#  'qtum': '/currencies/qtum/',
#  'ripple': '/currencies/ripple/',
#  'stellar': '/currencies/stellar/',
#  'stratis': '/currencies/stratis/',
#  'verge': '/currencies/verge/',
#  'zcash': '/currencies/zcash/'}

# %%
currencies_list = []

# %%
for i in currencies_dict:
    currencies_list.append(currencies_dict[i].split('/')[2])

# %%
train_crypto_data_list_df = []
for i in currencies_list:
    train_crypto_data_list_df.append(pd.read_html("https://coinmarketcap.com/currencies/"+i+"/historical-data/?start=20130428&end=20171231")[0])

# %%
test_crypto_data_list_df = []
for i in currencies_list:
    test_crypto_data_list_df.append(pd.read_html("https://coinmarketcap.com/currencies/"+i+"/historical-data/?start=20180101&end="+time.strftime("%Y%m%d"))[0])

# %%
count = 0
for i in train_crypto_data_list_df:
    i.to_csv('./CoinsData03262018/Train/'+currencies_list[count]+".csv")
    count = count +1

# %%
count = 0
for i in test_crypto_data_list_df:
    i.to_csv('./CoinsData03262018/Test/'+currencies_list[count]+".csv")
    count = count +1

# %%
crypto_symbol_name = list(crypto_coin.head(20)['Name'])

# %%
train_crypto_agg = pd.DataFrame()
for i in range(0,20):
    temp_coin_df = train_crypto_data_list_df[i][['Date','Open']]
    temp_coin_df['Name'] = crypto_symbol_name[i]
    train_crypto_agg = pd.concat([train_crypto_agg, temp_coin_df])

train_crypto_agg['Date'] = train_crypto_agg['Date'].apply(lambda s: dt.datetime.strptime(s, '%b %d, %Y'))
train_crypto_agg = train_crypto_agg.pivot(index='Name', columns='Date', values='Open').fillna(0)
train_crypto_agg.to_csv('./CoinsData03262018/TrainAgg.csv')
# Out:
# /Users/vsanjeev/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
test_crypto_agg = pd.DataFrame()
for i in range(0,20):
    temp_coin_df = test_crypto_data_list_df[i][['Date','Open']]
    temp_coin_df['Name'] = crypto_symbol_name[i]
    test_crypto_agg = pd.concat([test_crypto_agg, temp_coin_df])

test_crypto_agg['Date'] = test_crypto_agg['Date'].apply(lambda s: dt.datetime.strptime(s, '%b %d, %Y'))
test_crypto_agg = test_crypto_agg.pivot(index='Name', columns='Date', values='Open').fillna(0)
test_crypto_agg.to_csv('./CoinsData03262018/TestAgg.csv')
# Out:
# /Users/vsanjeev/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%